# %%
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler

import numpy as np
import pandas as pd
import math
import glob
import time
import pickle

import steering
import speeding

import logging

# %%
PROJECT_ROOT = '../../../..'
LEARNED_DRIVER = 'snakeoil_miner/data'
DIFFICULTY = 'easy'

# COMMAND = 'steering'
COMMAND = 'speeding'
logging.basicConfig(filename='logs/{}/training-{}.log'.format(COMMAND, time.time()),level=logging.DEBUG)

NUM_EPOCHS = 100

TRAINING_FILES = glob.glob('/'.join([PROJECT_ROOT, LEARNED_DRIVER, DIFFICULTY, '*.csv']))
TRAINING_DATA = {}
for FILE in TRAINING_FILES:
    DF = pd.read_csv(FILE, index_col=False)
    TRAINING_DATA[FILE] = DF.values

VALIDATION_FILES = glob.glob('/'.join([PROJECT_ROOT, LEARNED_DRIVER, 'validation', '*.csv']))
VALIDATION_DATA = {}
for FILE in VALIDATION_FILES:
    DF = pd.read_csv(FILE, index_col=False)
    VALIDATION_DATA[FILE] = DF.values
    
CUDA = torch.cuda.is_available()
if CUDA:
    DTYPE = torch.cuda.FloatTensor
else:
    DTYPE = torch.FloatTensor

# %%
def save_checkpoint(state, is_best, filepath='latest_checkpoint.tar'):
    torch.save(state, 'split_checkpoints/' + COMMAND + '/' + filepath)
    if is_best:
        torch.save(state, 'split_checkpoints/' + COMMAND + '/' + 'best_checkpoint.tar')

# %%
def train(training_data, model, criterion, optimzier):
    loss = 0
    model.train(mode=True)
    for key in training_data:
        logging.info('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        print('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        
        model.hidden_state = model.init_hidden()
        optimizer.zero_grad()
        track_sequence = training_data[key]

        if COMMAND == 'steering':
            targets = track_sequence[:, 2:3]
        elif COMMAND == 'speeding':
            targets = track_sequence[:, 0:2]
        
        inputs = track_sequence[:, 3:]

        targets_variable = autograd.Variable(torch.Tensor(targets)).type(DTYPE)
        inputs_variable = autograd.Variable(torch.Tensor(inputs),  requires_grad=True).type(DTYPE)

        outputs_variable = model(inputs_variable)

        track_loss = criterion(outputs_variable, targets_variable)

        track_loss.backward()
        optimizer.step()

        loss += track_loss.data[0]
    return loss

# %%
def validate(validation_data, model, criterion):
    loss = 0
    model.train(mode=False)
    for key in validation_data:
        logging.info('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        print('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        
        model.hidden_state = model.init_hidden()
        track_sequence = validation_data[key]

        if COMMAND == 'steering':
            targets = track_sequence[:, 2:3]
        elif COMMAND == 'speeding':
            targets = track_sequence[:, 0:2]
            
        inputs = track_sequence[:, 3:]

        targets_variable = autograd.Variable(torch.Tensor(targets), volatile=True).type(DTYPE)
        inputs_variable = autograd.Variable(torch.Tensor(inputs), volatile=True).type(DTYPE)

        outputs_variable = model(inputs_variable)

        track_loss = criterion(outputs_variable, targets_variable)

        loss += track_loss.data[0]
    return loss

# %%
if COMMAND == 'steering':
    model = steering.Steering(steering.HYPERPARAMS.INPUT_SIZE,
                               steering.HYPERPARAMS.LSTM_HIDDEN_SIZE,
                               steering.HYPERPARAMS.HIDDEN_LAYER_SIZE,
                               steering.HYPERPARAMS.DROPOUT_PROB,
                               steering.HYPERPARAMS.NUM_LAYERS,
                               steering.HYPERPARAMS.TARGET_SIZE,
                               steering.HYPERPARAMS.BATCH_SIZE)
    optimizer = optim.Adam(model.parameters(), lr=steering.HYPERPARAMS.LEARNING_RATE)
elif COMMAND == 'speeding':
    model = speeding.Speeding(speeding.HYPERPARAMS.INPUT_SIZE,
                               speeding.HYPERPARAMS.LSTM_HIDDEN_SIZE,
                               speeding.HYPERPARAMS.HIDDEN_LAYER_SIZE,
                               speeding.HYPERPARAMS.DROPOUT_PROB,
                               speeding.HYPERPARAMS.NUM_LAYERS,
                               speeding.HYPERPARAMS.TARGET_SIZE,
                               speeding.HYPERPARAMS.BATCH_SIZE)
    optimizer = optim.Adam(model.parameters(), lr=speeding.HYPERPARAMS.LEARNING_RATE)
if CUDA:
    model.cuda()
        
criterion = nn.MSELoss().cuda()

scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', verbose=True)

min_loss = math.inf
losses = {
  'training': [],
  'validation': []
}

# %%
logging.info('Training %s...' % COMMAND)
print('Training %s...' % COMMAND)

for epoch in np.arange(NUM_EPOCHS):
    logging.info('Epoch [%d/%d]' %(epoch+1, NUM_EPOCHS))
    print('Epoch [%d/%d]' %(epoch+1, NUM_EPOCHS))
    
    is_best = False

    training_loss = train(TRAINING_DATA, model, criterion, optimizer)
    logging.info('--- TRAINING LOSS: %f' % training_loss)
    print('--- TRAINING LOSS: %f' % training_loss)

    validation_loss = validate(VALIDATION_DATA, model, criterion)
    logging.info('--- VALIDATION LOSS: %f' % validation_loss)
    print('--- VALIDATION LOSS: %f' % validation_loss)

    if validation_loss < min_loss:
        logging.info('--- --- best model found so far: %f' % validation_loss)
        print('--- --- best model found so far: %f' % validation_loss)
        min_loss = validation_loss
        is_best = True

    losses['training'].append(training_loss)
    losses['validation'].append(validation_loss)

    save_checkpoint({
          'epoch': epoch + 1,
          'state_dict': model.state_dict(),
          'min_loss': min_loss,
          'optimizer' : optimizer.state_dict(),
      }, is_best)

    scheduler.step(validation_loss)
    logging.info('-------------------------------------------------------')
    print('-------------------------------------------------------')
# Out:
# Training speeding...
# Epoch [1/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 1.326058
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.363587
# --- --- best model found so far: 0.363587
# -------------------------------------------------------
# Epoch [2/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.475373
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.468537
# -------------------------------------------------------
# Epoch [3/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.429062
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.298180
# --- --- best model found so far: 0.298180
# -------------------------------------------------------
# Epoch [4/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.328492
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.289848
# --- --- best model found so far: 0.289848
# -------------------------------------------------------
# Epoch [5/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.347269
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.269615
# --- --- best model found so far: 0.269615
# -------------------------------------------------------
# Epoch [6/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.317836
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.248582
# --- --- best model found so far: 0.248582
# -------------------------------------------------------
# Epoch [7/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.296589
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.242613
# --- --- best model found so far: 0.242613
# -------------------------------------------------------
# Epoch [8/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.287253
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.235636
# --- --- best model found so far: 0.235636
# -------------------------------------------------------
# Epoch [9/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.278899
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.234875
# --- --- best model found so far: 0.234875
# -------------------------------------------------------
# Epoch [10/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.270069
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.232378
# --- --- best model found so far: 0.232378
# -------------------------------------------------------
# Epoch [11/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.263622
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.228651
# --- --- best model found so far: 0.228651
# -------------------------------------------------------
# Epoch [12/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.256895
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.232545
# -------------------------------------------------------
# Epoch [13/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.252000
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.229636
# -------------------------------------------------------
# Epoch [14/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.245246
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.228986
# -------------------------------------------------------
# Epoch [15/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.242289
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.224566
# --- --- best model found so far: 0.224566
# -------------------------------------------------------
# Epoch [16/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.234904
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.236210
# -------------------------------------------------------
# Epoch [17/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.234829
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.223381
# --- --- best model found so far: 0.223381
# -------------------------------------------------------
# Epoch [18/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.229859
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.244486
# -------------------------------------------------------
# Epoch [19/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.227927
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.223365
# --- --- best model found so far: 0.223365
# -------------------------------------------------------
# Epoch [20/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.235332
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.260958
# -------------------------------------------------------
# Epoch [21/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.255714
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.241031
# -------------------------------------------------------
# Epoch [22/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.227557
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.234766
# -------------------------------------------------------
# Epoch [23/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.227441
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.229277
# -------------------------------------------------------
# Epoch [24/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.220125
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.224885
# -------------------------------------------------------
# Epoch [25/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.212503
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.219158
# --- --- best model found so far: 0.219158
# -------------------------------------------------------
# Epoch [26/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.207069
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.225621
# -------------------------------------------------------
# Epoch [27/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.201046
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.218823
# --- --- best model found so far: 0.218823
# -------------------------------------------------------
# Epoch [28/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.199142
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.218205
# --- --- best model found so far: 0.218205
# -------------------------------------------------------
# Epoch [29/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.193687
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.214005
# --- --- best model found so far: 0.214005
# -------------------------------------------------------
# Epoch [30/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.190877
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.223862
# -------------------------------------------------------
# Epoch [31/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.190507
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.215690
# -------------------------------------------------------
# Epoch [32/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.193323
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.247850
# -------------------------------------------------------
# Epoch [33/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.196366
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.218729
# -------------------------------------------------------
# Epoch [34/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.204555
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.262706
# -------------------------------------------------------
# Epoch [35/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.229488
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.228707
# -------------------------------------------------------
# Epoch [36/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.200925
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.226677
# -------------------------------------------------------
# Epoch [37/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.195387
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.226538
# -------------------------------------------------------
# Epoch [38/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.192560
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.213908
# --- --- best model found so far: 0.213908
# -------------------------------------------------------
# Epoch [39/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.185699
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.211568
# --- --- best model found so far: 0.211568
# -------------------------------------------------------
# Epoch [40/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.183351
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.214029
# -------------------------------------------------------
# Epoch [41/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.174949
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.202310
# --- --- best model found so far: 0.202310
# -------------------------------------------------------
# Epoch [42/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.172891
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.207275
# -------------------------------------------------------
# Epoch [43/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.169317
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.199371
# --- --- best model found so far: 0.199371
# -------------------------------------------------------
# Epoch [44/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.166024
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.209849
# -------------------------------------------------------
# Epoch [45/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.169880
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.201678
# -------------------------------------------------------
# Epoch [46/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.179988
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.237114
# -------------------------------------------------------
# Epoch [47/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.193364
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.212785
# -------------------------------------------------------
# Epoch [48/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.177586
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.201656
# -------------------------------------------------------
# Epoch [49/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.172739
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.207693
# -------------------------------------------------------
# Epoch [50/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.165482
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.199968
# -------------------------------------------------------
# Epoch [51/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.162857
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.198063
# --- --- best model found so far: 0.198063
# -------------------------------------------------------
# Epoch [52/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.158025
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.201952
# -------------------------------------------------------
# Epoch [53/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.155376
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.195040
# --- --- best model found so far: 0.195040
# -------------------------------------------------------
# Epoch [54/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.150900
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.206155
# -------------------------------------------------------
# Epoch [55/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.152346
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.196685
# -------------------------------------------------------
# Epoch [56/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.159634
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.238574
# -------------------------------------------------------
# Epoch [57/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.168044
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.194414
# --- --- best model found so far: 0.194414
# -------------------------------------------------------
# Epoch [58/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.168344
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.220821
# -------------------------------------------------------
# Epoch [59/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.170990
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.194531
# -------------------------------------------------------
# Epoch [60/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.173085
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.203582
# -------------------------------------------------------
# Epoch [61/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.179131
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.206964
# -------------------------------------------------------
# Epoch [62/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.170292
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.202962
# -------------------------------------------------------
# Epoch [63/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.171180
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.210110
# -------------------------------------------------------
# Epoch [64/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.160950
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.200256
# -------------------------------------------------------
# Epoch [65/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.159061
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.199373
# -------------------------------------------------------
# Epoch [66/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.156508
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.193917
# --- --- best model found so far: 0.193917
# -------------------------------------------------------
# Epoch [67/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.155139
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.226608
# -------------------------------------------------------
# Epoch [68/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.158825
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.192485
# --- --- best model found so far: 0.192485
# -------------------------------------------------------
# Epoch [69/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.160736
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.205938
# -------------------------------------------------------
# Epoch [70/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.163448
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.191147
# --- --- best model found so far: 0.191147
# -------------------------------------------------------
# Epoch [71/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.160407
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.193253
# -------------------------------------------------------
# Epoch [72/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.155141
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.193814
# -------------------------------------------------------
# Epoch [73/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.148037
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.186742
# --- --- best model found so far: 0.186742
# -------------------------------------------------------
# Epoch [74/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.143015
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.190154
# -------------------------------------------------------
# Epoch [75/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.140086
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.190666
# -------------------------------------------------------
# Epoch [76/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.137286
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.196968
# -------------------------------------------------------
# Epoch [77/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.141835
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.193997
# -------------------------------------------------------
# Epoch [78/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.139747
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.204978
# -------------------------------------------------------
# Epoch [79/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.147906
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.185936
# --- --- best model found so far: 0.185936
# -------------------------------------------------------
# Epoch [80/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.150741
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.231796
# -------------------------------------------------------
# Epoch [81/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.190725
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.200646
# -------------------------------------------------------
# Epoch [82/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.179348
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.216554
# -------------------------------------------------------
# Epoch [83/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.190297
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.234175
# -------------------------------------------------------
# Epoch [84/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.172173
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.208672
# -------------------------------------------------------
# Epoch [85/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.168778
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.207911
# -------------------------------------------------------
# Epoch [86/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.160406
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.210759
# -------------------------------------------------------
# Epoch [87/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.157547
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.206575
# -------------------------------------------------------
# Epoch [88/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.151528
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.199962
# -------------------------------------------------------
# Epoch [89/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.148577
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.203721
# -------------------------------------------------------
# Epoch [90/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.147127
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.196422
# Epoch    89: reducing learning rate of group 0 to 1.0000e-04.
# -------------------------------------------------------
# Epoch [91/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.142344
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.196321
# -------------------------------------------------------
# Epoch [92/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.140135
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.196799
# -------------------------------------------------------
# Epoch [93/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.138540
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.198085
# -------------------------------------------------------
# Epoch [94/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.137832
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.198475
# -------------------------------------------------------
# Epoch [95/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.137228
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.197934
# -------------------------------------------------------
# Epoch [96/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.136494
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.197331
# -------------------------------------------------------
# Epoch [97/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.135940
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.196952
# -------------------------------------------------------
# Epoch [98/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.134832
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.196826
# -------------------------------------------------------
# Epoch [99/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.134924
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.196889
# -------------------------------------------------------
# Epoch [100/100]
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track easy-race_00.csv
# --- TRAINING LOSS: 0.134026
# --- Parsing track validation-race_32.csv
# --- Parsing track validation-race_33.csv
# --- Parsing track validation-race_31.csv
# --- Parsing track validation-race_30.csv
# --- VALIDATION LOSS: 0.197076
# -------------------------------------------------------

# %%
# dump losses to file
with open('split_checkpoints/{}/losses.pkl'.format(COMMAND, time.time()), 'wb') as file:
    pickle.dump(losses, file)

# %%
# test dump worked
with open('split_checkpoints/{}/losses.pkl'.format(COMMAND, time.time()), 'rb') as file:
    hello = pickle.load(file)
hello
# Out:
# {'training': [1.326058343052864,
#   0.4753730669617653,
#   0.42906247824430466,
#   0.3284917715936899,
#   0.3472686782479286,
#   0.31783611699938774,
#   0.2965888734906912,
#   0.28725307807326317,
#   0.2788986284285784,
#   0.2700688075274229,
#   0.26362208649516106,
#   0.256895350292325,
#   0.2520000971853733,
#   0.24524609372019768,
#   0.24228928238153458,
#   0.23490421287715435,
#   0.23482870496809483,
#   0.22985862009227276,
#   0.22792719677090645,
#   0.23533153161406517,
#   0.2557136807590723,
#   0.2275574915111065,
#   0.22744071669876575,
#   0.22012536693364382,
#   0.21250298898667097,
#   0.20706928987056017,
#   0.20104627218097448,
#   0.19914198759943247,
#   0.1936870589852333,
#   0.19087705854326487,
#   0.19050700683146715,
#   0.19332316052168608,
#   0.19636610802263021,
#   0.20455515757203102,
#   0.22948798350989819,
#   0.20092535018920898,
#   0.19538725167512894,
#   0.1925596771761775,
#   0.18569886032491922,
#   0.18335076980292797,
#   0.17494900058954954,
#   0.17289138585329056,
#   0.16931734699755907,
#   0.16602392960339785,
#   0.1698802812024951,
#   0.17998848017305136,
#   0.1933640018105507,
#   0.17758608609437943,
#   0.17273855488747358,
#   0.16548210568726063,
#   0.16285724099725485,
#   0.1580252517014742,
#   0.15537555888295174,
#   0.15089968452230096,
#   0.15234616259112954,
#   0.15963425347581506,
#   0.16804386768490076,
#   0.16834402829408646,
#   0.17098982818424702,
#   0.1730851111933589,
#   0.1791313891299069,
#   0.17029205290600657,
#   0.17118037771433592,
#   0.16095044277608395,
#   0.15906118229031563,
#   0.15650780778378248,
#   0.15513865696266294,
#   0.15882472833618522,
#   0.1607358893379569,
#   0.16344814095646143,
#   0.1604074933566153,
#   0.1551409992389381,
#   0.14803678123280406,
#   0.14301516208797693,
#   0.1400864622555673,
#   0.1372860507108271,
#   0.14183473400771618,
#   0.13974713813513517,
#   0.14790605986490846,
#   0.1507411040365696,
#   0.19072512164711952,
#   0.17934763804078102,
#   0.19029707740992308,
#   0.17217330634593964,
#   0.16877789655700326,
#   0.16040643211454153,
#   0.1575471111573279,
#   0.15152780944481492,
#   0.14857678720727563,
#   0.14712663926184177,
#   0.14234448224306107,
#   0.14013523515313864,
#   0.1385395065881312,
#   0.13783190585672855,
#   0.13722785795107484,
#   0.13649363536387682,
#   0.13594037061557174,
#   0.13483160408213735,
#   0.13492408441379666,
#   0.13402604777365923],
#  'validation': [0.3635868430137634,
#   0.46853672806173563,
#   0.2981803771108389,
#   0.2898484729230404,
#   0.2696145083755255,
#   0.24858176335692406,
#   0.24261340079829097,
#   0.23563563637435436,
#   0.23487519146874547,
#   0.23237772285938263,
#   0.2286505838856101,
#   0.23254505591467023,
#   0.22963600978255272,
#   0.2289861044846475,
#   0.22456596372649074,
#   0.23620995203964412,
#   0.22338145831599832,
#   0.2444862094707787,
#   0.22336520347744226,
#   0.2609578100964427,
#   0.2410308481194079,
#   0.23476566560566425,
#   0.2292770075146109,
#   0.22488497593440115,
#   0.2191584133543074,
#   0.22562069026753306,
#   0.21882320358417928,
#   0.21820536185987294,
#   0.21400527842342854,
#   0.22386188455857337,
#   0.21568968845531344,
#   0.24785046093165874,
#   0.2187292780727148,
#   0.2627059449441731,
#   0.22870685905218124,
#   0.2266770750284195,
#   0.2265380136668682,
#   0.21390760503709316,
#   0.21156825916841626,
#   0.2140294429846108,
#   0.202310438035056,
#   0.2072745596524328,
#   0.1993707495275885,
#   0.2098491988144815,
#   0.20167772006243467,
#   0.23711364972405136,
#   0.21278506331145763,
#   0.20165565772913396,
#   0.20769275189377367,
#   0.19996799319051206,
#   0.19806325971148908,
#   0.2019516231957823,
#   0.1950402343645692,
#   0.20615543005988002,
#   0.19668462127447128,
#   0.23857378447428346,
#   0.194414384663105,
#   0.22082118317484856,
#   0.19453129963949323,
#   0.20358151872642338,
#   0.20696416962891817,
#   0.20296152401715517,
#   0.2101097828708589,
#   0.20025615370832384,
#   0.1993732824921608,
#   0.19391698110848665,
#   0.22660849709063768,
#   0.1924846787005663,
#   0.2059384125750512,
#   0.19114686455577612,
#   0.19325325172394514,
#   0.19381394051015377,
#   0.18674162682145834,
#   0.19015418412163854,
#   0.1906661377288401,
#   0.19696801621466875,
#   0.1939972888212651,
#   0.20497752376832068,
#   0.18593639438040555,
#   0.23179632960818708,
#   0.20064631383866072,
#   0.21655368153005838,
#   0.23417499661445618,
#   0.20867219846695662,
#   0.20791124156676233,
#   0.21075906418263912,
#   0.20657488983124495,
#   0.19996214914135635,
#   0.2037205940578133,
#   0.19642236782237887,
#   0.19632078520953655,
#   0.19679910992272198,
#   0.1980853765271604,
#   0.19847496692091227,
#   0.19793423591181636,
#   0.19733105972409248,
#   0.19695189432241023,
#   0.1968257373664528,
#   0.19688895251601934,
#   0.1970760221593082]}
