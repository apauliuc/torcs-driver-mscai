# %%
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler

import numpy as np
import pandas as pd
import math
import glob
import time
import pickle

import steering
import speeding

import logging

# %%
PROJECT_ROOT = '../../../..'
LEARNED_DRIVER = 'snakeoil_miner/data'
DIFFICULTY = ['easy', 'medium', 'hard']

# COMMAND = 'steering'
COMMAND = 'speeding'
logging.basicConfig(filename='logs/{}/training-{}.log'.format(COMMAND, time.time()),level=logging.DEBUG)

NUM_EPOCHS = 200

TRAINING_FILES = []
for d in DIFFICULTY:
    TRAINING_FILES.extend(glob.glob('/'.join([PROJECT_ROOT, LEARNED_DRIVER, d, '*.csv'])))

TRAINING_DATA = {}
for FILE in TRAINING_FILES:
    DF = pd.read_csv(FILE, index_col=False)
    TRAINING_DATA[FILE] = DF.values
    
CUDA = torch.cuda.is_available()
if CUDA:
    DTYPE = torch.cuda.FloatTensor
else:
    DTYPE = torch.FloatTensor

# %%
def save_checkpoint(state, is_best, filepath='latest_checkpoint.tar'):
    torch.save(state, 'split_checkpoints/' + COMMAND + '/' + filepath)
    if is_best:
        torch.save(state, 'split_checkpoints/' + COMMAND + '/' + 'best_checkpoint.tar')

# %%
def train(training_data, model, criterion, optimzier):
    loss = 0
    model.train(mode=True)
    for key in training_data:
        logging.info('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        print('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        
        model.hidden_state = model.init_hidden()
        optimizer.zero_grad()
        track_sequence = training_data[key]

        if COMMAND == 'steering':
            targets = track_sequence[:, 2:3]
        elif COMMAND == 'speeding':
            targets = track_sequence[:, 0:2]
        
        inputs = track_sequence[:, 3:]

        targets_variable = autograd.Variable(torch.Tensor(targets)).type(DTYPE)
        inputs_variable = autograd.Variable(torch.Tensor(inputs),  requires_grad=True).type(DTYPE)

        outputs_variable = model(inputs_variable)

        track_loss = criterion(outputs_variable, targets_variable)

        track_loss.backward()
        optimizer.step()

        loss += track_loss.data[0]
    return loss

# %%
def validate(validation_data, model, criterion):
    loss = 0
    model.train(mode=False)
    for key in validation_data:
        logging.info('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        print('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        
        model.hidden_state = model.init_hidden()
        track_sequence = validation_data[key]

        if COMMAND == 'steering':
            targets = track_sequence[:, 2:3]
        elif COMMAND == 'speeding':
            targets = track_sequence[:, 0:2]
            
        inputs = track_sequence[:, 3:]

        targets_variable = autograd.Variable(torch.Tensor(targets), volatile=True).type(DTYPE)
        inputs_variable = autograd.Variable(torch.Tensor(inputs), volatile=True).type(DTYPE)

        outputs_variable = model(inputs_variable)

        track_loss = criterion(outputs_variable, targets_variable)

        loss += track_loss.data[0]
    return loss

# %%
if COMMAND == 'steering':
    model = steering.Steering(steering.HYPERPARAMS.INPUT_SIZE,
                               steering.HYPERPARAMS.LSTM_HIDDEN_SIZE,
                               steering.HYPERPARAMS.HIDDEN_LAYER_SIZE,
                               steering.HYPERPARAMS.DROPOUT_PROB,
                               steering.HYPERPARAMS.NUM_LAYERS,
                               steering.HYPERPARAMS.TARGET_SIZE,
                               steering.HYPERPARAMS.BATCH_SIZE)
    optimizer = optim.Adam(model.parameters(), lr=steering.HYPERPARAMS.LEARNING_RATE)
elif COMMAND == 'speeding':
    model = speeding.Speeding(speeding.HYPERPARAMS.INPUT_SIZE,
                               speeding.HYPERPARAMS.LSTM_HIDDEN_SIZE,
                               speeding.HYPERPARAMS.HIDDEN_LAYER_SIZE,
                               speeding.HYPERPARAMS.DROPOUT_PROB,
                               speeding.HYPERPARAMS.NUM_LAYERS,
                               speeding.HYPERPARAMS.TARGET_SIZE,
                               speeding.HYPERPARAMS.BATCH_SIZE)
    optimizer = optim.Adam(model.parameters(), lr=speeding.HYPERPARAMS.LEARNING_RATE)
if CUDA:
    model.cuda()
        
criterion = nn.MSELoss().cuda()

scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', verbose=True)

min_loss = math.inf
losses = {
  'training': [],
  'validation': []
}

# %%
logging.info('Training %s...' % COMMAND)
print('Training %s...' % COMMAND)

for epoch in np.arange(NUM_EPOCHS):
    logging.info('Epoch [%d/%d]' %(epoch+1, NUM_EPOCHS))
    print('Epoch [%d/%d]' %(epoch+1, NUM_EPOCHS))
    
    is_best = False

    training_loss = train(TRAINING_DATA, model, criterion, optimizer)
    logging.info('--- TRAINING LOSS: %f' % training_loss)
    print('--- TRAINING LOSS: %f' % training_loss)

#     validation_loss = validate(VALIDATION_DATA, model, criterion)
#     logging.info('--- VALIDATION LOSS: %f' % validation_loss)
#     print('--- VALIDATION LOSS: %f' % validation_loss)

    if training_loss < min_loss:
        logging.info('--- --- best model found so far: %f' % training_loss)
        print('--- --- best model found so far: %f' % training_loss)
        min_loss = training_loss
        is_best = True

    losses['training'].append(training_loss)
#     losses['validation'].append(validation_loss)

    save_checkpoint({
          'epoch': epoch + 1,
          'state_dict': model.state_dict(),
          'min_loss': min_loss,
          'optimizer' : optimizer.state_dict(),
      }, is_best)

    scheduler.step(training_loss)
    logging.info('-------------------------------------------------------')
    print('-------------------------------------------------------')
# Out:
# Training speeding...
# Epoch [1/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 1.540664
# --- --- best model found so far: 1.540664
# -------------------------------------------------------
# Epoch [2/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.966666
# --- --- best model found so far: 0.966666
# -------------------------------------------------------
# Epoch [3/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.904464
# --- --- best model found so far: 0.904464
# -------------------------------------------------------
# Epoch [4/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.865174
# --- --- best model found so far: 0.865174
# -------------------------------------------------------
# Epoch [5/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.871413
# -------------------------------------------------------
# Epoch [6/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.832488
# --- --- best model found so far: 0.832488
# -------------------------------------------------------
# Epoch [7/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.845292
# -------------------------------------------------------
# Epoch [8/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.802806
# --- --- best model found so far: 0.802806
# -------------------------------------------------------
# Epoch [9/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.783874
# --- --- best model found so far: 0.783874
# -------------------------------------------------------
# Epoch [10/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.768097
# --- --- best model found so far: 0.768097
# -------------------------------------------------------
# Epoch [11/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.807492
# -------------------------------------------------------
# Epoch [12/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.741351
# -------------------------------------------------------
# Epoch [20/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.779156
# -------------------------------------------------------
# Epoch [21/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.756718
# -------------------------------------------------------
# Epoch [22/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.762690
# -------------------------------------------------------
# Epoch [23/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.745814
# -------------------------------------------------------
# Epoch [24/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.729313
# -------------------------------------------------------
# Epoch [25/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.730223
# -------------------------------------------------------
# Epoch [26/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.703001
# --- --- best model found so far: 0.703001
# -------------------------------------------------------
# Epoch [27/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.694783
# --- --- best model found so far: 0.694783
# -------------------------------------------------------
# Epoch [28/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.731165
# -------------------------------------------------------
# Epoch [29/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.714672
# -------------------------------------------------------
# Epoch [30/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.711928
# -------------------------------------------------------
# Epoch [31/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.743636
# -------------------------------------------------------
# Epoch [32/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.719038
# -------------------------------------------------------
# Epoch [33/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.708018
# -------------------------------------------------------
# Epoch [34/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.703596
# -------------------------------------------------------
# Epoch [35/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.682094
# --- --- best model found so far: 0.682094
# -------------------------------------------------------
# Epoch [36/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.692670
# -------------------------------------------------------
# Epoch [37/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.710813
# -------------------------------------------------------
# Epoch [38/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.703903
# -------------------------------------------------------
# Epoch [39/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.690243
# -------------------------------------------------------
# Epoch [40/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.677723
# --- --- best model found so far: 0.677723
# -------------------------------------------------------
# Epoch [41/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.704651
# -------------------------------------------------------
# Epoch [42/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.724988
# -------------------------------------------------------
# Epoch [43/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.681992
# -------------------------------------------------------
# Epoch [44/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.681371
# -------------------------------------------------------
# Epoch [45/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.658116
# --- --- best model found so far: 0.658116
# -------------------------------------------------------
# Epoch [46/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.671665
# -------------------------------------------------------
# Epoch [47/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.755676
# -------------------------------------------------------
# Epoch [48/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.709857
# -------------------------------------------------------
# Epoch [49/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.705579
# -------------------------------------------------------
# Epoch [50/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.668682
# -------------------------------------------------------
# Epoch [51/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.679933
# -------------------------------------------------------
# Epoch [52/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.668710
# -------------------------------------------------------
# Epoch [53/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.724157
# -------------------------------------------------------
# Epoch [54/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.722613
# -------------------------------------------------------
# Epoch [55/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.698056
# -------------------------------------------------------
# Epoch [56/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.709706
# Epoch    55: reducing learning rate of group 0 to 1.0000e-04.
# -------------------------------------------------------
# Epoch [57/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.729601
# -------------------------------------------------------
# Epoch [58/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.656632
# --- --- best model found so far: 0.656632
# -------------------------------------------------------
# Epoch [59/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.643808
# --- --- best model found so far: 0.643808
# -------------------------------------------------------
# Epoch [60/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.631340
# --- --- best model found so far: 0.631340
# -------------------------------------------------------
# Epoch [61/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.621335
# --- --- best model found so far: 0.621335
# -------------------------------------------------------
# Epoch [62/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.616681
# --- --- best model found so far: 0.616681
# -------------------------------------------------------
# Epoch [63/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.611154
# --- --- best model found so far: 0.611154
# -------------------------------------------------------
# Epoch [64/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.606944
# --- --- best model found so far: 0.606944
# -------------------------------------------------------
# Epoch [65/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.601785
# --- --- best model found so far: 0.601785
# -------------------------------------------------------
# Epoch [66/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.597963
# --- --- best model found so far: 0.597963
# -------------------------------------------------------
# Epoch [67/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.595170
# --- --- best model found so far: 0.595170
# -------------------------------------------------------
# Epoch [68/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.592681
# --- --- best model found so far: 0.592681
# -------------------------------------------------------
# Epoch [69/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.589296
# --- --- best model found so far: 0.589296
# -------------------------------------------------------
# Epoch [70/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.585534
# --- --- best model found so far: 0.585534
# -------------------------------------------------------
# Epoch [71/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.582348
# --- --- best model found so far: 0.582348
# -------------------------------------------------------
# Epoch [72/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.580766
# --- --- best model found so far: 0.580766
# -------------------------------------------------------
# Epoch [73/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.577088
# --- --- best model found so far: 0.577088
# -------------------------------------------------------
# Epoch [74/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.575246
# --- --- best model found so far: 0.575246
# -------------------------------------------------------
# Epoch [75/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.572525
# --- --- best model found so far: 0.572525
# -------------------------------------------------------
# Epoch [76/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.569916
# --- --- best model found so far: 0.569916
# -------------------------------------------------------
# Epoch [77/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.568022
# --- --- best model found so far: 0.568022
# -------------------------------------------------------
# Epoch [78/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.565291
# --- --- best model found so far: 0.565291
# -------------------------------------------------------
# Epoch [79/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.564820
# --- --- best model found so far: 0.564820
# -------------------------------------------------------
# Epoch [80/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.561378
# --- --- best model found so far: 0.561378
# -------------------------------------------------------
# Epoch [81/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.561981
# -------------------------------------------------------
# Epoch [82/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.560910
# --- --- best model found so far: 0.560910
# -------------------------------------------------------
# Epoch [83/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.558566
# --- --- best model found so far: 0.558566
# -------------------------------------------------------
# Epoch [84/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.556867
# --- --- best model found so far: 0.556867
# -------------------------------------------------------
# Epoch [85/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.551460
# --- --- best model found so far: 0.551460
# -------------------------------------------------------
# Epoch [86/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.551540
# -------------------------------------------------------
# Epoch [87/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.549012
# --- --- best model found so far: 0.549012
# -------------------------------------------------------
# Epoch [88/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.552475
# -------------------------------------------------------
# Epoch [89/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.554713
# -------------------------------------------------------
# Epoch [90/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.546388
# --- --- best model found so far: 0.546388
# -------------------------------------------------------
# Epoch [91/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.545384
# --- --- best model found so far: 0.545384
# -------------------------------------------------------
# Epoch [92/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.545133
# --- --- best model found so far: 0.545133
# -------------------------------------------------------
# Epoch [93/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.525895
# --- --- best model found so far: 0.525895
# -------------------------------------------------------
# Epoch [109/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.526763
# ...
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.454338
# -------------------------------------------------------
# Epoch [164/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.457432
# -------------------------------------------------------
# Epoch [165/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.453642
# -------------------------------------------------------
# Epoch [166/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.468449
# -------------------------------------------------------
# Epoch [167/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.466938
# -------------------------------------------------------
# Epoch [168/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.458552
# -------------------------------------------------------
# Epoch [169/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.451879
# -------------------------------------------------------
# Epoch [170/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.458654
# -------------------------------------------------------
# Epoch [171/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.454982
# -------------------------------------------------------
# Epoch [172/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.446817
# --- --- best model found so far: 0.446817
# -------------------------------------------------------
# Epoch [173/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.448982
# -------------------------------------------------------
# Epoch [174/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.453349
# -------------------------------------------------------
# Epoch [175/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.450297
# -------------------------------------------------------
# Epoch [176/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.443259
# --- --- best model found so far: 0.443259
# -------------------------------------------------------
# Epoch [177/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.448263
# -------------------------------------------------------
# Epoch [178/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.435091
# -------------------------------------------------------
# Epoch [187/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.429853
# --- --- best model found so far: 0.429853
# -------------------------------------------------------
# Epoch [188/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.429870
# -------------------------------------------------------
# Epoch [189/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.433559
# -------------------------------------------------------
# Epoch [190/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.433968
# -------------------------------------------------------
# Epoch [191/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.428052
# --- --- best model found so far: 0.428052
# -------------------------------------------------------
# Epoch [192/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.433913
# -------------------------------------------------------
# Epoch [193/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.434662
# -------------------------------------------------------
# Epoch [194/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.431622
# -------------------------------------------------------
# Epoch [195/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.421538
# --- --- best model found so far: 0.421538
# -------------------------------------------------------
# Epoch [196/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.424913
# -------------------------------------------------------
# Epoch [197/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.427830
# -------------------------------------------------------
# Epoch [198/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.426130
# -------------------------------------------------------
# Epoch [199/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.419016
# --- --- best model found so far: 0.419016
# -------------------------------------------------------
# Epoch [200/200]
# --- Parsing track medium-race_10.csv
# --- Parsing track easy-race_03.csv
# --- Parsing track hard-race_22.csv
# --- Parsing track easy-race_00.csv
# --- Parsing track easy-race_02.csv
# --- Parsing track hard-race_21.csv
# --- Parsing track medium-race_13.csv
# --- Parsing track easy-race_01.csv
# --- Parsing track hard-race_20.csv
# --- Parsing track medium-race_12.csv
# --- Parsing track hard-race_23.csv
# --- Parsing track medium-race_11.csv
# --- TRAINING LOSS: 0.423557
# -------------------------------------------------------

# %%
# dump losses to file
with open('split_checkpoints/{}/losses.pkl'.format(COMMAND), 'wb') as file:
    pickle.dump(losses, file)

# %%
# test dump worked
with open('split_checkpoints/{}/losses.pkl'.format(COMMAND), 'rb') as file:
    hello = pickle.load(file)
hello
# Out:
# {'training': [1.540663681924343,
#   0.9666658975183964,
#   0.9044640175998211,
#   0.8651743708178401,
#   0.8714125948026776,
#   0.8324881340377033,
#   0.8452917858958244,
#   0.8028058307245374,
#   0.7838735990226269,
#   0.7680966397747397,
#   0.8074919544160366,
#   0.7939923061057925,
#   0.7470022384077311,
#   0.786412313580513,
#   0.761294384021312,
#   0.7697959402576089,
#   0.74113236553967,
#   0.7234220542013645,
#   0.7413505865260959,
#   0.7791558029130101,
#   0.7567182113416493,
#   0.7626897236332297,
#   0.7458144295960665,
#   0.7293128417804837,
#   0.7302228212356567,
#   0.7030009124428034,
#   0.6947828317061067,
#   0.7311645993031561,
#   0.7146716946735978,
#   0.7119283801876009,
#   0.7436360297724605,
#   0.7190381116233766,
#   0.7080178428441286,
#   0.7035957584157586,
#   0.6820943844504654,
#   0.6926703187637031,
#   0.7108126860111952,
#   0.7039025644771755,
#   0.6902434686198831,
#   0.6777229667641222,
#   0.7046507289633155,
#   0.7249881140887737,
#   0.681992347817868,
#   0.6813712902367115,
#   0.6581161804497242,
#   0.6716648181900382,
#   0.7556760152801871,
#   0.7098574247211218,
#   0.7055792938917875,
#   0.6686818208545446,
#   0.679932652041316,
#   0.6687095523811877,
#   0.7241571433842182,
#   0.7226130031049252,
#   0.6980557478964329,
#   0.7097062282264233,
#   0.7296010847203434,
#   0.6566323763690889,
#   0.643807721324265,
#   0.6313404068350792,
#   0.6213348358869553,
#   0.6166810696013272,
#   0.6111539965495467,
#   0.6069436268880963,
#   0.601784648373723,
#   0.5979628837667406,
#   0.5951698175631464,
#   0.5926806963980198,
#   0.5892958273179829,
#   0.5855336273089051,
#   0.582348046824336,
#   0.5807658536359668,
#   0.5770877674221992,
#   0.5752462414093316,
#   0.5725245480425656,
#   0.5699164704419672,
#   0.5680218674242496,
#   0.5652909888885915,
#   0.564820006955415,
#   0.56137779308483,
#   0.5619811583310366,
#   0.5609104777686298,
#   0.5585657702758908,
#   0.5568671240471303,
#   0.5514599005691707,
#   0.5515396776609123,
#   0.5490117082372308,
#   0.5524747353047132,
#   0.5547131863422692,
#   0.5463882577605546,
#   0.5453838598914444,
#   0.5451330747455359,
#   0.5511731160804629,
#   0.5552360978908837,
#   0.5389003455638885,
#   0.5438533746637404,
#   0.5552528076805174,
#   0.5420612432062626,
#   0.5394109855405986,
#   0.5371861993335187,
#   0.5368028306402266,
#   0.5373458261601627,
#   0.5271610859781504,
#   0.5293231084942818,
#   0.5362409395165741,
#   0.5305331349372864,
#   0.5281132403761148,
#   0.5258953399024904,
#   0.5267628999426961,
#   0.5257149399258196,
#   0.5152735486626625,
#   0.5202576578594744,
#   0.5270883133634925,
#   0.516857712995261,
#   0.5158789833076298,
#   0.5178246349096298,
#   0.5144261950626969,
#   0.5146093014627695,
#   0.5133390654809773,
#   0.5121472212485969,
#   0.5116727356798947,
#   0.5052450019866228,
#   0.5094358962960541,
#   0.5100345853716135,
#   0.4996938956901431,
#   0.5026650102809072,
#   0.5048012742772698,
#   0.49720415147021413,
#   0.4961651205085218,
#   0.49437942262738943,
#   0.49123542103916407,
#   0.4902112213894725,
#   0.48701613023877144,
#   0.4838753938674927,
#   0.48288498679175973,
#   0.4814210473559797,
#   0.48389158491045237,
#   0.48632920533418655,
#   0.4832908711396158,
#   0.478888520039618,
#   0.47305230749771,
#   0.46775644179433584,
#   0.4751826603896916,
#   0.4780105999670923,
#   0.4809819729998708,
#   0.47104521421715617,
#   0.4865064066834748,
#   0.4817854752764106,
#   0.4775179522112012,
#   0.465246990788728,
#   0.4611060721799731,
#   0.4699831251055002,
#   0.46657234570011497,
#   0.4628313039429486,
#   0.4583518970757723,
#   0.45699310256168246,
#   0.47532986104488373,
#   0.47748021176084876,
#   0.46285361982882023,
#   0.45265390956774354,
#   0.4497453640215099,
#   0.4574310905300081,
#   0.45433754101395607,
#   0.4574319338425994,
#   0.4536419864743948,
#   0.46844889083877206,
#   0.4669380420818925,
#   0.4585521980188787,
#   0.45187908923253417,
#   0.45865371730178595,
#   0.45498240599408746,
#   0.446816673502326,
#   0.44898214004933834,
#   0.45334926433861256,
#   0.45029686391353607,
#   0.44325861195102334,
#   0.4482631180435419,
#   0.4517459231428802,
#   0.44367900118231773,
#   0.43593808682635427,
#   0.43824391113594174,
#   0.43980678310617805,
#   0.43443300714716315,
#   0.43203340470790863,
#   0.435185806825757,
#   0.4350911546498537,
#   0.4298529885709286,
#   0.4298697696067393,
#   0.4335589958354831,
#   0.43396793119609356,
#   0.4280521215405315,
#   0.43391348561272025,
#   0.43466229387558997,
#   0.4316222839988768,
#   0.42153788753785193,
#   0.4249127940274775,
#   0.42782992287538946,
#   0.4261298740748316,
#   0.4190163884777576,
#   0.42355678509920835],
#  'validation': []}
