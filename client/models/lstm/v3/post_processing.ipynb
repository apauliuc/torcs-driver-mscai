# %%
import pickle
import glob
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# speeding_loss = pickle.load(open('split_checkpoints/speeding/losses_1513064763.380457.pkl'))
steering_loss = pickle.load(open('split_checkpoints/steering/losses.pkl', 'rb'))

plt.plot(steering_loss['training'])

# %%
files = glob.glob('split_checkpoints/speeding/*.pkl')
speeding_loss = []
for file in files:
    loss = pickle.load(open(file, 'rb'))
    speeding_loss.extend(loss['training'])

# %%
plt.plot(speeding_loss)
