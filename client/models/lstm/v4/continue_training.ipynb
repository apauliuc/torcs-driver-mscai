# %%
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler

import numpy as np
import pandas as pd
import math
import glob
import time
import pickle

import steering
import speeding

import logging

# %%
PROJECT_ROOT = '../../../..'
LEARNED_DRIVER = 'default_miner/data'


# COMMAND = 'steering'
COMMAND = 'speeding'
logging.basicConfig(filename='logs/{}/training-{}.log'.format(COMMAND, time.time()),level=logging.DEBUG)

NUM_EPOCHS = 50

DIFFICULTY = ['easy', 'medium']
TRAINING_FILES = []
for d in DIFFICULTY:
    TRAINING_FILES.extend(glob.glob('/'.join([PROJECT_ROOT, LEARNED_DRIVER, d, '*.csv'])))
TRAINING_DATA = {}
for FILE in TRAINING_FILES:
    DF = pd.read_csv(FILE, index_col=False)
    TRAINING_DATA[FILE] = DF.values

VALIDATION_FILES = glob.glob('/'.join([PROJECT_ROOT, LEARNED_DRIVER, 'validation', '*.csv']))
VALIDATION_DATA = {}
for FILE in VALIDATION_FILES:
    DF = pd.read_csv(FILE, index_col=False)
    VALIDATION_DATA[FILE] = DF.values
    
CUDA = torch.cuda.is_available()
if CUDA:
    DTYPE = torch.cuda.FloatTensor
else:
    DTYPE = torch.FloatTensor

# %%
def save_checkpoint(state, is_best, filepath='latest_checkpoint.tar'):
    torch.save(state, 'split_checkpoints/' + DIFFICULTY[-1] + '/' + COMMAND + '/' + filepath)
    if is_best:
        torch.save(state, 'split_checkpoints/' + DIFFICULTY[-1] + '/' + COMMAND + '/' + 'best_checkpoint.tar')

# %%
def train(training_data, model, criterion, optimzier):
    loss = 0
    model.train(mode=True)
    for key in training_data:
        logging.info('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        print('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        
        model.hidden_state = model.init_hidden()
        optimizer.zero_grad()
        track_sequence = training_data[key]

        if COMMAND == 'steering':
            targets = track_sequence[:, 2:3]
        elif COMMAND == 'speeding':
            targets = track_sequence[:, 0:2]
        
        inputs = track_sequence[:, 3:]

        targets_variable = autograd.Variable(torch.Tensor(targets)).type(DTYPE)
        inputs_variable = autograd.Variable(torch.Tensor(inputs),  requires_grad=True).type(DTYPE)

        outputs_variable = model(inputs_variable)

        track_loss = criterion(outputs_variable, targets_variable)

        track_loss.backward()
        optimizer.step()

        loss += track_loss.data[0]
    return loss

# %%
def validate(validation_data, model, criterion):
    loss = 0
    model.train(mode=False)
    for key in validation_data:
        logging.info('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        print('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        
        model.hidden_state = model.init_hidden()
        track_sequence = validation_data[key]

        if COMMAND == 'steering':
            targets = track_sequence[:, 2:3]
        elif COMMAND == 'speeding':
            targets = track_sequence[:, 0:2]
            
        inputs = track_sequence[:, 3:]

        targets_variable = autograd.Variable(torch.Tensor(targets), volatile=True).type(DTYPE)
        inputs_variable = autograd.Variable(torch.Tensor(inputs), volatile=True).type(DTYPE)

        outputs_variable = model(inputs_variable)

        track_loss = criterion(outputs_variable, targets_variable)

        loss += track_loss.data[0]
    return loss

# %%
checkpoint = torch.load('split_checkpoints/easy/{}/latest_checkpoint.tar'.format(COMMAND))
if COMMAND == 'steering':
    model = steering.Steering(steering.HYPERPARAMS.INPUT_SIZE,
                               steering.HYPERPARAMS.LSTM_HIDDEN_SIZE,
                               steering.HYPERPARAMS.HIDDEN_LAYER_SIZE,
                               steering.HYPERPARAMS.DROPOUT_PROB,
                               steering.HYPERPARAMS.NUM_LAYERS,
                               steering.HYPERPARAMS.TARGET_SIZE,
                               steering.HYPERPARAMS.BATCH_SIZE)
    optimizer = optim.Adam(model.parameters(), lr=steering.HYPERPARAMS.LEARNING_RATE)
elif COMMAND == 'speeding':
    model = speeding.Speeding(speeding.HYPERPARAMS.INPUT_SIZE,
                               speeding.HYPERPARAMS.LSTM_HIDDEN_SIZE,
                               speeding.HYPERPARAMS.HIDDEN_LAYER_SIZE,
                               speeding.HYPERPARAMS.DROPOUT_PROB,
                               speeding.HYPERPARAMS.NUM_LAYERS,
                               speeding.HYPERPARAMS.TARGET_SIZE,
                               speeding.HYPERPARAMS.BATCH_SIZE)
    optimizer = optim.Adam(model.parameters(), lr=speeding.HYPERPARAMS.LEARNING_RATE)

model.load_state_dict(checkpoint['state_dict'])
optimizer.load_state_dict(checkpoint['optimizer'])
min_loss = math.inf
if CUDA:
    model.cuda()
    criterion = nn.MSELoss().cuda()

scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', verbose=True)
losses = {
  'training': [],
  'validation': []
}

# %%
for epoch in np.arange(NUM_EPOCHS):
    logging.info('Epoch [%d/%d]' %(epoch+1, NUM_EPOCHS))
    print('Epoch [%d/%d]' %(epoch+1, NUM_EPOCHS))
    
    is_best = False

    training_loss = train(TRAINING_DATA, model, criterion, optimizer)
    logging.info('--- TRAINING LOSS: %f' % training_loss)
    print('--- TRAINING LOSS: %f' % training_loss)

#     validation_loss = validate(VALIDATION_DATA, model, criterion)
#     logging.info('--- VALIDATION LOSS: %f' % validation_loss)
#     print('--- VALIDATION LOSS: %f' % validation_loss)

    if training_loss < min_loss:
        logging.info('--- --- best model found so far: %f' % training_loss)
        print('--- --- best model found so far: %f' % training_loss)
        min_loss = training_loss
        is_best = True

    losses['training'].append(training_loss)
#     losses['validation'].append(validation_loss)

    save_checkpoint({
          'epoch': epoch + 1,
          'state_dict': model.state_dict(),
          'min_loss': min_loss,
          'optimizer' : optimizer.state_dict(),
      }, is_best)

    scheduler.step(training_loss)
    logging.info('-------------------------------------------------------')
    print('-------------------------------------------------------')
# Out:
# Epoch [1/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.115677
# --- --- best model found so far: 0.115677
# -------------------------------------------------------
# Epoch [2/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.091477
# --- --- best model found so far: 0.091477
# -------------------------------------------------------
# Epoch [3/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.094480
# -------------------------------------------------------
# Epoch [4/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.094780
# -------------------------------------------------------
# Epoch [5/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.065829
# --- --- best model found so far: 0.065829
# -------------------------------------------------------
# Epoch [6/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.051547
# --- --- best model found so far: 0.051547
# -------------------------------------------------------
# Epoch [7/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.049563
# --- --- best model found so far: 0.049563
# -------------------------------------------------------
# Epoch [8/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.042161
# --- --- best model found so far: 0.042161
# -------------------------------------------------------
# Epoch [9/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.037668
# --- --- best model found so far: 0.037668
# -------------------------------------------------------
# Epoch [10/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.040910
# -------------------------------------------------------
# Epoch [11/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.027888
# --- --- best model found so far: 0.027888
# -------------------------------------------------------
# Epoch [12/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.031216
# -------------------------------------------------------
# Epoch [13/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.044479
# -------------------------------------------------------
# Epoch [14/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.032853
# -------------------------------------------------------
# Epoch [15/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.031632
# -------------------------------------------------------
# Epoch [16/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.038655
# -------------------------------------------------------
# Epoch [17/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.030109
# -------------------------------------------------------
# Epoch [18/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.025962
# --- --- best model found so far: 0.025962
# -------------------------------------------------------
# Epoch [19/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.026564
# -------------------------------------------------------
# Epoch [20/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.019982
# --- --- best model found so far: 0.019982
# -------------------------------------------------------
# Epoch [21/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.017666
# --- --- best model found so far: 0.017666
# -------------------------------------------------------
# Epoch [22/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.015533
# --- --- best model found so far: 0.015533
# -------------------------------------------------------
# Epoch [23/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.014962
# --- --- best model found so far: 0.014962
# -------------------------------------------------------
# Epoch [24/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.016789
# -------------------------------------------------------
# Epoch [25/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.015580
# -------------------------------------------------------
# Epoch [26/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.015243
# -------------------------------------------------------
# Epoch [27/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.012915
# --- --- best model found so far: 0.012915
# -------------------------------------------------------
# Epoch [28/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.011931
# --- --- best model found so far: 0.011931
# -------------------------------------------------------
# Epoch [29/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.012399
# -------------------------------------------------------
# Epoch [30/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.012585
# -------------------------------------------------------
# Epoch [31/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.013355
# -------------------------------------------------------
# Epoch [32/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.017438
# -------------------------------------------------------
# Epoch [33/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.027276
# -------------------------------------------------------
# Epoch [34/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.019482
# -------------------------------------------------------
# Epoch [35/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.016227
# -------------------------------------------------------
# Epoch [36/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.016887
# -------------------------------------------------------
# Epoch [37/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.019593
# -------------------------------------------------------
# Epoch [38/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.015217
# -------------------------------------------------------
# Epoch [39/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.013009
# Epoch    38: reducing learning rate of group 0 to 1.0000e-04.
# -------------------------------------------------------
# Epoch [40/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.011963
# -------------------------------------------------------
# Epoch [41/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.011578
# --- --- best model found so far: 0.011578
# -------------------------------------------------------
# Epoch [42/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.011199
# --- --- best model found so far: 0.011199
# -------------------------------------------------------
# Epoch [43/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.010809
# --- --- best model found so far: 0.010809
# -------------------------------------------------------
# Epoch [44/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.010479
# --- --- best model found so far: 0.010479
# -------------------------------------------------------
# Epoch [45/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.010389
# --- --- best model found so far: 0.010389
# -------------------------------------------------------
# Epoch [46/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.010281
# --- --- best model found so far: 0.010281
# -------------------------------------------------------
# Epoch [47/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.010162
# --- --- best model found so far: 0.010162
# -------------------------------------------------------
# Epoch [48/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.010515
# -------------------------------------------------------
# Epoch [49/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.010055
# --- --- best model found so far: 0.010055
# -------------------------------------------------------
# Epoch [50/50]
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track medium-race_COET.csv
# --- Parsing track easy-race_UXES.csv
# --- Parsing track medium-race_YZEY.csv
# --- Parsing track medium-race_CYWR.csv
# --- Parsing track medium-race_KAFP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.009928
# --- --- best model found so far: 0.009928
# -------------------------------------------------------

# %%
# dump losses to file
with open('split_checkpoints/{}/{}/losses_{}.pkl'.format(DIFFICULTY[-1], COMMAND, time.time()), 'wb') as file:
    pickle.dump(losses, file)
