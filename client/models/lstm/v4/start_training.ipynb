# %%
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler

import numpy as np
import pandas as pd
import math
import glob
import time
import pickle

import steering
import speeding

import logging

# %%
PROJECT_ROOT = '../../../..'
LEARNED_DRIVER = 'default_miner/data'
DIFFICULTY = 'easy'

COMMAND = 'steering'
# COMMAND = 'speeding'
logging.basicConfig(filename='logs/{}/training-{}.log'.format(COMMAND, time.time()),level=logging.DEBUG)

NUM_EPOCHS = 100

TRAINING_FILES = glob.glob('/'.join([PROJECT_ROOT, LEARNED_DRIVER, DIFFICULTY, '*.csv']))
TRAINING_DATA = {}
for FILE in TRAINING_FILES:
    DF = pd.read_csv(FILE, index_col=False)
    TRAINING_DATA[FILE] = DF.values

VALIDATION_FILES = glob.glob('/'.join([PROJECT_ROOT, LEARNED_DRIVER, 'validation', '*.csv']))
VALIDATION_DATA = {}
for FILE in VALIDATION_FILES:
    DF = pd.read_csv(FILE, index_col=False)
    VALIDATION_DATA[FILE] = DF.values
    
CUDA = torch.cuda.is_available()
if CUDA:
    DTYPE = torch.cuda.FloatTensor
else:
    DTYPE = torch.FloatTensor

# %%
def save_checkpoint(state, is_best, filepath='latest_checkpoint.tar'):
    torch.save(state, 'split_checkpoints/' + COMMAND + '/' + filepath)
    if is_best:
        torch.save(state, 'split_checkpoints/' + COMMAND + '/' + 'best_checkpoint.tar')

# %%
def train(training_data, model, criterion, optimzier):
    loss = 0
    model.train(mode=True)
    for key in training_data:
        logging.info('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        print('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        
        model.hidden_state = model.init_hidden()
        optimizer.zero_grad()
        track_sequence = training_data[key]

        if COMMAND == 'steering':
            targets = track_sequence[:, 2:3]
        elif COMMAND == 'speeding':
            targets = track_sequence[:, 0:2]
        
        inputs = track_sequence[:, 3:]

        targets_variable = autograd.Variable(torch.Tensor(targets)).type(DTYPE)
        inputs_variable = autograd.Variable(torch.Tensor(inputs),  requires_grad=True).type(DTYPE)

        outputs_variable = model(inputs_variable)

        track_loss = criterion(outputs_variable, targets_variable)

        track_loss.backward()
        optimizer.step()

        loss += track_loss.data[0]
    return loss

# %%
def validate(validation_data, model, criterion):
    loss = 0
    model.train(mode=False)
    for key in validation_data:
        logging.info('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        print('--- Parsing track {}-{}'.format(key.split('/')[-2], key.split('/')[-1]))
        
        model.hidden_state = model.init_hidden()
        track_sequence = validation_data[key]

        if COMMAND == 'steering':
            targets = track_sequence[:, 2:3]
        elif COMMAND == 'speeding':
            targets = track_sequence[:, 0:2]
            
        inputs = track_sequence[:, 3:]

        targets_variable = autograd.Variable(torch.Tensor(targets), volatile=True).type(DTYPE)
        inputs_variable = autograd.Variable(torch.Tensor(inputs), volatile=True).type(DTYPE)

        outputs_variable = model(inputs_variable)

        track_loss = criterion(outputs_variable, targets_variable)

        loss += track_loss.data[0]
    return loss

# %%
if COMMAND == 'steering':
    model = steering.Steering(steering.HYPERPARAMS.INPUT_SIZE,
                               steering.HYPERPARAMS.LSTM_HIDDEN_SIZE,
                               steering.HYPERPARAMS.HIDDEN_LAYER_SIZE,
                               steering.HYPERPARAMS.DROPOUT_PROB,
                               steering.HYPERPARAMS.NUM_LAYERS,
                               steering.HYPERPARAMS.TARGET_SIZE,
                               steering.HYPERPARAMS.BATCH_SIZE)
    optimizer = optim.Adam(model.parameters(), lr=steering.HYPERPARAMS.LEARNING_RATE)
elif COMMAND == 'speeding':
    model = speeding.Speeding(speeding.HYPERPARAMS.INPUT_SIZE,
                               speeding.HYPERPARAMS.LSTM_HIDDEN_SIZE,
                               speeding.HYPERPARAMS.HIDDEN_LAYER_SIZE,
                               speeding.HYPERPARAMS.DROPOUT_PROB,
                               speeding.HYPERPARAMS.NUM_LAYERS,
                               speeding.HYPERPARAMS.TARGET_SIZE,
                               speeding.HYPERPARAMS.BATCH_SIZE)
    optimizer = optim.Adam(model.parameters(), lr=speeding.HYPERPARAMS.LEARNING_RATE)
if CUDA:
    model.cuda()
        
criterion = nn.MSELoss().cuda()

scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', verbose=True)

min_loss = math.inf
losses = {
  'training': [],
  'validation': []
}

# %%
logging.info('Training %s...' % COMMAND)
print('Training %s...' % COMMAND)

for epoch in np.arange(NUM_EPOCHS):
    logging.info('Epoch [%d/%d]' %(epoch+1, NUM_EPOCHS))
    print('Epoch [%d/%d]' %(epoch+1, NUM_EPOCHS))
    
    is_best = False

    training_loss = train(TRAINING_DATA, model, criterion, optimizer)
    logging.info('--- TRAINING LOSS: %f' % training_loss)
    print('--- TRAINING LOSS: %f' % training_loss)

    validation_loss = validate(VALIDATION_DATA, model, criterion)
    logging.info('--- VALIDATION LOSS: %f' % validation_loss)
    print('--- VALIDATION LOSS: %f' % validation_loss)

    if validation_loss < min_loss:
        logging.info('--- --- best model found so far: %f' % validation_loss)
        print('--- --- best model found so far: %f' % validation_loss)
        min_loss = validation_loss
        is_best = True

    losses['training'].append(training_loss)
    losses['validation'].append(validation_loss)

    save_checkpoint({
          'epoch': epoch + 1,
          'state_dict': model.state_dict(),
          'min_loss': min_loss,
          'optimizer' : optimizer.state_dict(),
      }, is_best)

    scheduler.step(validation_loss)
    logging.info('-------------------------------------------------------')
    print('-------------------------------------------------------')
# Out:
# Training steering...
# Epoch [1/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.116638
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.038368
# --- --- best model found so far: 0.038368
# -------------------------------------------------------
# Epoch [2/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.095750
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.048104
# -------------------------------------------------------
# Epoch [3/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.085808
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.033765
# --- --- best model found so far: 0.033765
# -------------------------------------------------------
# Epoch [4/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.081850
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.033123
# --- --- best model found so far: 0.033123
# -------------------------------------------------------
# Epoch [5/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.072113
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.035315
# -------------------------------------------------------
# Epoch [6/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.068122
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.031737
# --- --- best model found so far: 0.031737
# -------------------------------------------------------
# Epoch [7/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.057715
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.031507
# --- --- best model found so far: 0.031507
# -------------------------------------------------------
# Epoch [8/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.046353
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.031363
# --- --- best model found so far: 0.031363
# -------------------------------------------------------
# Epoch [9/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.034533
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.033518
# -------------------------------------------------------
# Epoch [10/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.026314
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.030665
# --- --- best model found so far: 0.030665
# -------------------------------------------------------
# Epoch [11/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.019503
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.032054
# -------------------------------------------------------
# Epoch [12/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.016172
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.032278
# -------------------------------------------------------
# Epoch [13/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.013385
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.031301
# -------------------------------------------------------
# Epoch [14/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.011114
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.030868
# -------------------------------------------------------
# Epoch [15/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.008447
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.030085
# --- --- best model found so far: 0.030085
# -------------------------------------------------------
# Epoch [16/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.007431
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.029637
# --- --- best model found so far: 0.029637
# -------------------------------------------------------
# Epoch [17/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.006389
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.030249
# -------------------------------------------------------
# Epoch [18/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.005697
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.030079
# -------------------------------------------------------
# Epoch [19/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.005084
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.030020
# -------------------------------------------------------
# Epoch [20/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.004580
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.029590
# --- --- best model found so far: 0.029590
# -------------------------------------------------------
# Epoch [21/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.004248
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.029856
# -------------------------------------------------------
# Epoch [22/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.003951
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.029646
# -------------------------------------------------------
# Epoch [23/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.003689
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.029858
# -------------------------------------------------------
# Epoch [24/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.003415
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.029412
# --- --- best model found so far: 0.029412
# -------------------------------------------------------
# Epoch [25/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.003273
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.029606
# -------------------------------------------------------
# Epoch [26/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.003104
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027829
# --- --- best model found so far: 0.027829
# -------------------------------------------------------
# Epoch [27/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.003124
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028629
# -------------------------------------------------------
# Epoch [28/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.003136
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027588
# --- --- best model found so far: 0.027588
# -------------------------------------------------------
# Epoch [29/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.002910
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027470
# --- --- best model found so far: 0.027470
# -------------------------------------------------------
# Epoch [30/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.002815
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027423
# --- --- best model found so far: 0.027423
# -------------------------------------------------------
# Epoch [31/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.002648
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027246
# --- --- best model found so far: 0.027246
# -------------------------------------------------------
# Epoch [32/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.002546
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027308
# -------------------------------------------------------
# Epoch [33/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.002427
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027333
# -------------------------------------------------------
# Epoch [34/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.002344
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027402
# -------------------------------------------------------
# Epoch [35/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.002246
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027310
# -------------------------------------------------------
# Epoch [36/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.002169
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027467
# -------------------------------------------------------
# Epoch [37/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.002091
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027528
# -------------------------------------------------------
# Epoch [38/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.002001
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027548
# -------------------------------------------------------
# Epoch [39/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001974
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.027765
# -------------------------------------------------------
# Epoch [40/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001887
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028110
# -------------------------------------------------------
# Epoch [41/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001833
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028160
# -------------------------------------------------------
# Epoch [42/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001890
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028839
# Epoch    41: reducing learning rate of group 0 to 1.0000e-04.
# -------------------------------------------------------
# Epoch [43/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001862
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028614
# -------------------------------------------------------
# Epoch [44/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001807
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028328
# -------------------------------------------------------
# Epoch [45/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001741
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028179
# -------------------------------------------------------
# Epoch [46/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001701
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028141
# -------------------------------------------------------
# Epoch [47/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001720
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028128
# -------------------------------------------------------
# Epoch [48/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001674
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028120
# -------------------------------------------------------
# Epoch [49/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001717
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028123
# -------------------------------------------------------
# Epoch [50/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001654
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028139
# -------------------------------------------------------
# Epoch [51/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001679
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028160
# -------------------------------------------------------
# Epoch [52/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001666
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028183
# -------------------------------------------------------
# Epoch [53/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001669
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028198
# Epoch    52: reducing learning rate of group 0 to 1.0000e-05.
# -------------------------------------------------------
# Epoch [54/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001638
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028199
# -------------------------------------------------------
# Epoch [55/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001671
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028199
# -------------------------------------------------------
# Epoch [56/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001635
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028199
# -------------------------------------------------------
# Epoch [57/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001622
# --- Parsing track validation-race_BVUX.csv
# --- Parsing track validation-race_PVEP.csv
# --- Parsing track validation-race_UMBJ.csv
# --- Parsing track validation-race_VBHG.csv
# --- VALIDATION LOSS: 0.028199
# -------------------------------------------------------
# Epoch [58/100]
# --- Parsing track easy-race_UXES.csv
# --- Parsing track easy-race_CDRV.csv
# --- Parsing track easy-race_QDWP.csv
# --- Parsing track easy-race_PVDY.csv
# --- TRAINING LOSS: 0.001652
# --- Parsing track validation-race_BVUX.csv

# %%
# dump losses to file
with open('split_checkpoints/{}/losses.pkl'.format(COMMAND, time.time()), 'wb') as file:
    pickle.dump(losses, file)

# %%
# test dump worked
with open('split_checkpoints/{}/losses.pkl'.format(COMMAND, time.time()), 'rb') as file:
    hello = pickle.load(file)
hello
